# %%
import pandas as pd
import ast

# %%
#leeremos el json y lo pondremos en un dataframe
with open('dataset/steam_games.json') as f:
    rows = []
    for line in f.readlines():
        rows.append(ast.literal_eval(line))

    steam_games = pd.DataFrame(rows)

steam_games
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1      Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2          Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                  彼岸领域                        [Action, Adventure, Casual]
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 32131            Sacada                          [Casual, Indie, Strategy]
# 32132      Laush Studio                        [Indie, Racing, Simulation]
# 32133          SIXNAILS                                    [Casual, Indie]
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# ...

# %%
#eliminaremos las filas duplicadas como primer paso para limpiar nuestros datos en base a la columna url ya que es unica por juego
steam_games = steam_games.drop_duplicates(subset=['id'], keep='first')
steam_games
# Out:
#               publisher                                             genres  \
# 0             Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1      Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2          Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                  彼岸领域                        [Action, Adventure, Casual]
# 4                   NaN                                                NaN
# ...                 ...                                                ...
# 32130   Ghost_RUS Games              [Casual, Indie, Simulation, Strategy]
# 32131            Sacada                          [Casual, Indie, Strategy]
# 32132      Laush Studio                        [Indie, Racing, Simulation]
# 32133          SIXNAILS                                    [Casual, Indie]
# 32134               NaN                                                NaN
#
#                        app_name                     title  \
# ...

# %%
#Como podemos ver no hay duplicados en la tabla  mas que solo 2

# %%
steam_games['release_date'] = pd.to_datetime(steam_games['release_date'], errors='coerce')
#Eliminaremos los datos de la columna 'release date' que sean vacion o nulos
steam_games = steam_games.dropna(subset=['release_date', 'url'])
#eliminaremos los datos de la misma columna donde no haya numeros
steam_games
# Out:
# /var/folders/5r/4_p7m9h17bv8506l5bcbht940000gn/T/ipykernel_1594/726586130.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam_games['release_date'] = pd.to_datetime(steam_games['release_date'], errors='coerce')
#                  publisher                                             genres  \
# 0                Kotoshiro      [Action, Casual, Indie, Simulation, Strategy]
# 1         Making Fun, Inc.               [Free to Play, Indie, RPG, Strategy]
# 2             Poolians.com  [Casual, Free to Play, Indie, Simulation, Sports]
# 3                     彼岸领域                        [Action, Adventure, Casual]
# 5      Trickjump Games Ltd                    [Action, Adventure, Simulation]
# ...

# %%
#creamos una columna year que extrera el año de la columna release_date

steam_games['year'] = steam_games['release_date'].dt.year
steam_games['year'] = steam_games['year'].astype(int)
steam_games['year']
# Out:
# /var/folders/5r/4_p7m9h17bv8506l5bcbht940000gn/T/ipykernel_1594/518771046.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam_games['year'] = steam_games['release_date'].dt.year
# /var/folders/5r/4_p7m9h17bv8506l5bcbht940000gn/T/ipykernel_1594/518771046.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam_games['year'] = steam_games['year'].astype(int)
# 0        2018
# 1        2018
# 2        2017
# 3        2017
# 5        2018
#          ...
# 32129    2018
# 32130    2018
# ...

# %%
steam_games['genres'] = steam_games['genres'].fillna('Unknown')
# Out:
# /var/folders/5r/4_p7m9h17bv8506l5bcbht940000gn/T/ipykernel_1594/2888655429.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   steam_games['genres'] = steam_games['genres'].fillna('Unknown')
# 0            [Action, Casual, Indie, Simulation, Strategy]
# 1                     [Free to Play, Indie, RPG, Strategy]
# 2        [Casual, Free to Play, Indie, Simulation, Sports]
# 3                              [Action, Adventure, Casual]
# 5                          [Action, Adventure, Simulation]
#                                ...
# 32129                   [Action, Adventure, Casual, Indie]
# 32130                [Casual, Indie, Simulation, Strategy]
# 32131                            [Casual, Indie, Strategy]
# ...

# %%
#Convertimos a un csv
steam_games.to_csv('dataset/steam_games.csv', index=False)
